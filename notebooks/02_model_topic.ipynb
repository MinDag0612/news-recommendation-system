# %%
import os
import pandas as pd
import sys

project_root = os.path.abspath("..")   # lên 1 cấp: MIND-research

if project_root not in sys.path:
    sys.path.insert(0, project_root)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import pandas as pd
#       3 import sys
#       4
#       5 project_root = os.path.abspath("..")   # lên 1 cấp: MIND-research
#
# File d:\CDNC\MIND-research\.venv\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File d:\CDNC\MIND-research\.venv\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)     14     PeriodDtype,
#      15 )
#
# File d:\CDNC\MIND-research\.venv\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File d:\CDNC\MIND-research\.venv\Lib\site-packages\pandas\_libs\tslibs\__init__.py:39
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)     36     "is_supported_dtype",
#      37 ]
# ---> 39 from pandas._libs.tslibs import dtypes  # pylint: disable=import-self
#      40 from pandas._libs.tslibs.conversion import localize_pydatetime
#      41 from pandas._libs.tslibs.dtypes import (
#      42     Resolution,
#      43     periods_per_day,
#      44     periods_per_second,
#      45 )
#
# File dtypes.pyx:1, in init pandas._libs.tslibs.dtypes()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap>:405, in ModuleSpec.parent(self)
# --> 405 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
from src.core.Models import Models
from src.core.Context import VectorContext

from src.topic.BERTopicVector import BERTopicVector

# %%
context = VectorContext("data/primary/train_set")

title_list = context.createTitleList()

vector_df = pd.read_pickle("../vectors/primary/semantic_vectors.pkl")
semantic_vector_list = vector_df.set_index("News_ID")["semantic_vector"].to_dict()

# %%
model = Models()

bertopic_vector = BERTopicVector(model.topic_model)

topics_vector = bertopic_vector.get_vector(
    title_list, semantic_vector_list
)
# Out:
# 2026-09-14 18:20:30,331 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2026-09-14 18:21:24,243 - BERTopic - Dimensionality - Completed ✓
# 2026-09-14 18:21:24,327 - BERTopic - Cluster - Start clustering the reduced embeddings

# %%
import pickle

with open("../vectors/primary/topic_vectors.pkl", "wb") as f:
    pickle.dump(topics_vector, f)
    
bertopic_vector.model.save("../models/primary/bertopic")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pickle
#       2
#       3 with open("../vectors/primary/topic_vectors.pkl", "wb") as f:
# ----> 4     pickle.dump(topics_vector, f)
#       5
#       6 bertopic_vector.model.save("../models/primary/bertopic")
#
# NameError: name 'topics_vector' is not defined
